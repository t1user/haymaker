# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from pyfolio.timeseries import perf_stats
# %matplotlib inline

# %%
cash = 120000

# %%
df = pd.read_csv('/home/tomek/ib_tools/backtests/backtest_2020-09-02_17-27_20180601_20191231.csv')
del df['sys_time']
del df['exec_ids']
try:
    del df['perm_id']
    del df['com_reports']
except:
    pass
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)
df['cash'] = df.realizedPNL.cumsum() + cash
df['contract'] = df['contract'].apply(lambda x: x[:-2])
df['contract'] = df['contract'].apply(lambda x: x[:2])

# %%
df[df['reason']=='CLOSE'].realizedPNL.count()/df.realizedPNL.count()*2
# Out:
# 0.06832627118644068

# %%
#df = df[(df['contract'] == 'NQ') | (df['contract'] == 'ES') | (df['contract'] == 'YM')]

# %%
#df = df.loc['20190101':'20190701']

# %%
c = set(df['contract'])
allocs = pd.Series([1/len(c)]*len(c) +[1], index=list(c) + ['total'])
#allocs = pd.Series([1/3, 2/3, 1], index=['ES','NQ', 'total'])

# %%
allocs
# Out:
# ES       0.25
# NQ       0.25
# YM       0.25
# GC       0.25
# total    1.00
# dtype: float64

# %%
df.groupby('contract').realizedPNL.sum()
# Out:
# contract
# ES    19492.20
# GC    10986.76
# NQ    39234.60
# YM    30224.00
# Name: realizedPNL, dtype: float64

# %%
df.realizedPNL.sum()
# Out:
# 99937.56

# %%
df.cash.plot(figsize=(20,4), grid=True);

# %%
by_contract = pd.pivot_table(df, values='realizedPNL', index=df.index, columns=['contract'])
by_contract['total'] = by_contract.sum(axis=1)

# %%
# number of trades
trades = df.groupby('contract').action.count()
trades, trades.sum()
# Out:
# (contract
#  ES     468
#  GC    1023
#  NQ    1775
#  YM     510
#  Name: action, dtype: int64,
#  3776)

# %%
# trades per day
days = len(by_contract.resample('B').count().index)
trades/days, trades.sum()/days
# Out:
# (contract
#  ES    1.135922
#  GC    2.483010
#  NQ    4.308252
#  YM    1.237864
#  Name: action, dtype: float64,
#  9.16504854368932)

# %%
# commission paid
df.groupby('contract').commission.sum()
# Out:
# contract
# ES     982.80
# GC    2475.66
# NQ    3727.50
# YM    1071.00
# Name: commission, dtype: float64

# %%
df.commission.sum()
# Out:
# 8256.960000000003

# %%
# per trade stats
exits = df[df.realizedPNL!=0]
dfs = {}
for contract in exits.contract.unique():
    dfs[contract] = exits[exits.contract == contract]
dfs['total'] = exits
results = pd.DataFrame(columns=['success_rate', 'average_PNL', 'average_gain', 'average_loss','win_ratio', 'EV',
                               'number_of_positions'])
for c, d in dfs.items():
    row = pd.Series()
    row['success_rate'] = round((d[d.realizedPNL > 0]).realizedPNL.count() / d.realizedPNL.count(), 2)
    row['average_PNL'] = round(d.realizedPNL.mean(), 2)
    row['average_gain'] = round((d[d.realizedPNL > 0]).realizedPNL.mean(), 2)
    row['average_loss'] = round((d[d.realizedPNL < 0]).realizedPNL.mean(), 2)
    row['win_ratio'] = round(abs(row['average_gain'] / row['average_loss']), 2)
    row['EV'] = round((row['average_gain'] * row['success_rate']) + (
        row['average_loss'] * (1 - row['success_rate'])), 2)
    row['number_of_positions'] = d.realizedPNL.count()
    results.loc[c] = row
results
# Out:
#        success_rate  average_PNL  average_gain  average_loss  win_ratio  \
# GC             0.39        21.50        460.89       -258.75       1.78
# NQ             0.41        44.23        461.96       -245.14       1.88
# ES             0.43        83.30        913.25       -546.96       1.67
# YM             0.43       118.53        764.30       -371.37       2.06
# total          0.41        52.96        563.67       -301.42       1.87
#
#            EV  number_of_positions
# GC      21.91                511.0
# NQ      44.77                887.0
# ES      80.93                234.0
# YM     116.97                255.0
# total   53.27               1887.0

# %%
daily = by_contract.resample('B').sum()
daily = daily /  (allocs * cash)
#daily[['CL', 'ES', 'GC', 'NQ']].plot(figsize=(20,8), grid=True);

# %%
# instrument correlations
log_returns = np.log(daily + 1)
log_returns.corr()
# Out:
#              ES        GC        NQ        YM     total
# ES     1.000000  0.019169  0.174340  0.532279  0.739350
# GC     0.019169  1.000000  0.004385  0.051565  0.364562
# NQ     0.174340  0.004385  1.000000  0.204344  0.600897
# YM     0.532279  0.051565  0.204344  1.000000  0.728551
# total  0.739350  0.364562  0.600897  0.728551  1.000000

# %%
log_returns.cumsum().plot(figsize=(20,8), grid=True);

# %%
returns = daily.copy()
returns_index = (returns + 1).cumprod()
returns_index.plot(figsize=(20,8), grid=True);

# %%
stats = pd.DataFrame()
for col in daily.columns:
    stats[col] = perf_stats(daily[col])
stats
# Out:
#                             ES        GC        NQ        YM     total
# Annual return         0.396795  0.209247  1.093296  0.772597  0.631741
# Cumulative returns    0.726953  0.364286  2.346051  1.549515  1.226732
# Annual volatility     0.361925  0.262408  0.349689  0.298080  0.198496
# Sharpe ratio          1.098055  0.853640  2.287546  2.067286  2.566253
# Calmar ratio          2.236038  1.288991  6.746570  2.667920  7.890046
# Stability             0.497766  0.815979  0.927279  0.885325  0.929402
# Max drawdown         -0.177455 -0.162334 -0.162052 -0.289588 -0.080068
# Omega ratio           1.315704  1.180201  1.552143  1.680831  1.687206
# Sortino ratio         2.259408  1.500356  4.215032  4.629388  5.750377
# Skew                  2.459321  1.084885  0.860700  2.102331  2.231502
# Kurtosis             11.116578  3.410760  2.503117  7.134005  9.599065
# Tail ratio            1.670207  1.623534  1.580691  2.078938  1.701152
# Daily value at risk  -0.044021 -0.032171 -0.040882 -0.035109 -0.022987

# %%
# monthly returns in percent
monthly_log_returns = log_returns.resample('M').sum()
monthly_returns = np.exp(monthly_log_returns)-1
round(monthly_returns, 4) * 100
# Out:
#                ES     GC     NQ     YM  total
# time
# 2018-06-30   7.38   0.85 -10.22   3.87   0.36
# 2018-07-31   2.25   4.90  22.67   6.03   8.90
# 2018-08-31   5.56   8.58   5.41  -1.02   4.76
# 2018-09-30   0.86 -13.93  -3.65  -0.63  -4.40
# 2018-10-31  32.16   8.23  40.96  23.06  26.07
# 2018-11-30   2.23  -2.56  -3.79  10.69   1.97
# 2018-12-31   9.66   0.08  29.02  39.06  19.24
# 2019-01-31  -6.81   6.47   4.61 -16.86  -3.44
# 2019-02-28   8.37   0.50  -2.46  -2.19   1.10
# 2019-03-31  -4.16   6.45  -0.73  -7.49  -1.42
# 2019-04-30  -0.14  -3.11   8.14  -4.84   0.05
# 2019-05-31  -2.95   3.18  -8.00  12.72   1.17
# 2019-06-30   2.56   1.99  27.78  17.68  12.39
# 2019-07-31   1.60   4.58   5.70   7.93   5.21
# 2019-08-31  -8.52   9.52   0.57   1.70   1.05
# 2019-09-30  -2.57   7.29  -4.21   6.50   1.76
# 2019-10-31   4.49  -4.39   6.69   6.83   3.62
# 2019-11-30  -0.37  -0.92  11.29   2.11   3.12
# 2019-12-31   9.95  -3.31   9.83   2.61   4.86

# %%
# total returns by contract in percent
round(np.exp(monthly_log_returns.sum())-1, 2)* 100
# Out:
# ES        73.0
# GC        36.0
# NQ       235.0
# YM       155.0
# total    123.0
# dtype: float64

# %%
df.sort_values('realizedPNL', ascending=False)[['contract', 'action', 'price', 'realizedPNL']]
# Out:
#                     contract action     price  realizedPNL
# time
# 2019-10-02 20:49:00       ES    BUY   2893.50       4508.3
# 2018-11-08 13:33:30       ES   SELL   2806.50       4320.8
# 2018-10-11 04:24:00       ES    BUY   2767.00       3395.8
# 2018-12-17 17:03:00       ES    BUY   2597.00       3333.3
# 2019-08-05 21:19:00       YM    BUY  25615.00       3190.8
# ...                      ...    ...       ...          ...
# 2019-08-06 20:15:00       ES    BUY   2873.25      -1291.7
# 2018-12-10 13:56:30       ES    BUY   2638.75      -1329.2
# 2018-12-26 11:04:00       ES    BUY   2360.75      -1454.2
# 2019-01-02 16:09:00       ES    BUY   2488.75      -1529.2
# 2019-01-03 19:17:00       ES   SELL   2455.00      -1591.7
#
# [3776 rows x 4 columns]

# %%
daily.sort_values('total', ascending=False)
# Out:
#                   ES        GC        NQ        YM     total
# time
# 2019-10-02  0.150277  0.030688  0.026633  0.101693  0.077323
# 2019-08-05  0.109720  0.037011  0.035793  0.106360  0.072221
# 2019-09-05  0.072777  0.073011  0.070387  0.067220  0.070848
# 2018-12-03  0.067777 -0.003989  0.103553  0.081860  0.062300
# 2018-12-17  0.111110  0.000000  0.046440  0.043580  0.050283
# ...              ...       ...       ...       ...       ...
# 2019-06-26 -0.018890 -0.062979  0.000000  0.000000 -0.020467
# 2019-08-22 -0.046947 -0.000495 -0.032920 -0.020447 -0.025202
# 2019-01-02 -0.050973 -0.003495 -0.013920 -0.037973 -0.026590
# 2018-12-10 -0.051947 -0.001656 -0.061173 -0.000780 -0.028889
# 2019-01-03 -0.053057 -0.004828 -0.045393 -0.030307 -0.033396
#
# [412 rows x 5 columns]
