# %%
import pandas as pd

# %%
candles_nq = pd.read_pickle('/home/tomek/ib_tools/notebooks/freeze/live/freeze_df_NQU0.pickle')
candles_es = pd.read_pickle('/home/tomek/ib_tools/notebooks/freeze/live/freeze_df_ESU0.pickle')

# %%
candles_es
# Out:
#                      backfill     open     high      low    close    price  \
# date
# 2020-06-11 08:29:00      True  3173.00  3177.75  3126.50  3129.00  3129.00
# 2020-06-11 13:50:00      True  3129.00  3135.50  3105.25  3109.00  3109.00
# 2020-06-11 15:51:00      True  3109.00  3110.75  3086.00  3102.00  3102.00
# 2020-06-11 16:54:30      True  3102.00  3107.50  3080.75  3082.25  3082.25
# 2020-06-11 17:58:00      True  3082.00  3082.75  3057.25  3061.75  3061.75
# ...                       ...      ...      ...      ...      ...      ...
# 2020-07-07 07:18:30     False  3164.25  3167.75  3158.25  3164.00  3164.00
# 2020-07-07 09:26:00     False  3164.00  3164.50  3144.75  3146.25  3146.25
# 2020-07-07 11:04:30     False  3146.00  3157.75  3141.75  3142.75  3142.75
# 2020-07-07 12:41:00     False  3142.75  3150.00  3138.25  3146.50  3146.50
# 2020-07-07 14:27:00     False  3146.75  3154.00  3142.00  3148.75  3148.75
#
#                      volume     ema_fast     ema_slow        atr  signal  \
# date
# 2020-06-11 08:29:00   43019          NaN          NaN  51.250000     0.0
# 2020-06-11 13:50:00   43085          NaN          NaN  40.691667     0.0
# 2020-06-11 15:51:00   43394          NaN          NaN  35.318626     0.0
# 2020-06-11 16:54:30   43410          NaN          NaN  33.140635     0.0
# 2020-06-11 17:58:00   43276          NaN          NaN  31.578362     0.0
# ...                     ...          ...          ...        ...     ...
# 2020-07-07 07:18:30   43000  3124.953643  3093.267482   9.926824     0.0
# 2020-07-07 09:26:00   43192  3125.305656  3093.603445  10.035449     0.0
# 2020-07-07 11:04:30   43801  3125.593998  3093.915049  10.101404     0.0
# 2020-07-07 12:41:00   43147  3125.939559  3094.248417  10.119634     0.0
# 2020-07-07 14:27:00   43019  3126.316598  3094.593897  10.140426     0.0
#
#                      filter  filtered_signal
# date
# 2020-06-11 08:29:00     NaN              0.0
# 2020-06-11 13:50:00     NaN              0.0
# 2020-06-11 15:51:00     NaN              0.0
# 2020-06-11 16:54:30     NaN              0.0
# 2020-06-11 17:58:00     NaN              0.0
# ...                     ...              ...
# 2020-07-07 07:18:30     1.0              0.0
# 2020-07-07 09:26:00     1.0              0.0
# 2020-07-07 11:04:30     1.0              0.0
# 2020-07-07 12:41:00     1.0              0.0
# 2020-07-07 14:27:00     1.0              0.0
#
# [651 rows x 13 columns]

# %%
candles_es['vol'] = candles_es['price'].pct_change().rolling(180).std() * candles_es['price']
candles_es
# Out:
#                      backfill     open     high      low    close    price  \
# date
# 2020-06-11 08:29:00      True  3173.00  3177.75  3126.50  3129.00  3129.00
# 2020-06-11 13:50:00      True  3129.00  3135.50  3105.25  3109.00  3109.00
# 2020-06-11 15:51:00      True  3109.00  3110.75  3086.00  3102.00  3102.00
# 2020-07-07 13:45:30     False  10546.50  10565.75  10529.75  10561.50
#
#                         price  volume      ema_fast      ema_slow         atr  \
# date
# 2020-06-11 15:35:00   9907.50   12016           NaN           NaN  209.250000
# 2020-06-11 17:01:00   9863.50   12066           NaN           NaN  158.343750
# 2020-06-11 18:33:00   9794.50   12042           NaN           NaN  158.986240
# 2020-06-11 20:33:30   9674.00   12008   9771.092308           NaN  152.825824
# 2020-06-11 21:59:30   9578.25   12290   9697.062796           NaN  143.915919
# ...                       ...     ...           ...           ...         ...
# 2020-07-07 07:45:00  10595.25   12001  10602.504302  10370.995089   32.385351
# 2020-07-07 09:16:00  10559.00   12013  10588.002868  10374.102761   32.488967
# 2020-07-07 10:30:00  10545.25   12003  10573.751912  10376.931779   32.594202
# 2020-07-07 12:14:00  10546.25   12020  10564.584608  10379.730561   32.479750
# 2020-07-07 13:45:30  10561.50   12035  10563.556405  10382.735155   32.518699
#
#                      signal  filter  filtered_signal        vol
# date
# 2020-06-11 15:35:00     0.0     NaN              0.0        NaN
# 2020-06-11 17:01:00     0.0     NaN              0.0        NaN
# 2020-06-11 18:33:00     0.0     NaN              0.0        NaN
# 2020-06-11 20:33:30     0.0     NaN              0.0        NaN
# 2020-06-11 21:59:30     0.0     NaN              0.0        NaN
# ...                     ...     ...              ...        ...
# 2020-07-07 07:45:00     0.0     1.0              0.0  22.575263
# 2020-07-07 09:16:00     0.0     1.0              0.0  22.275744
# 2020-07-07 10:30:00     0.0     1.0              0.0  22.227419
# 2020-07-07 12:14:00     0.0     1.0              0.0  22.023363
# 2020-07-07 13:45:30     0.0     1.0              0.0  22.022719
#
# [598 rows x 14 columns]

# %%
ratio = candles_nq.atr / candles_nq.vol
ratio.plot(figsize=(20,10), grid=True);

# %%
contracts = {
    'NQ': {'multiplier': 20,
          'trades_per_day': 4.5,
          'atr': 14, 
          'atr_multiple': 1},
    'ES': {'multiplier': 50,
          'trades_per_day': .8,
           'atr': 12,
           'atr_multiple': 3
          },
    'GC': {'multiplier': 100,
          'trades_per_day': 3,
          'atr': 4.5,
          'atr_multiple': 2},
    'YM': {'multiplier': 5,
          'trades_per_day': 1.5,
          'atr': 135,
          'atr_multiple': 2}
}
multiplier_dict = {2: 1.35, 3:1.5, 4: 1.65}
target_vol = .5
div_multiplier = multiplier_dict[len(contracts)]
alloc = 1/len(contracts)
cash = 649701

# %%
def number_of_contracts(params: dict, target_vol: float = target_vol, cash: int = cash, alloc: float = alloc):
    daily_vol = target_vol / 16
    daily_cash_alloc = daily_vol * cash * alloc
    cash_alloc_per_trade = daily_cash_alloc / (params['trades_per_day'] ** .5)
    points_alloc_per_trade = cash_alloc_per_trade / params['multiplier']
    contracts = points_alloc_per_trade / ((params['atr'] / 1.4) * params['atr_multiple'])
    return round(contracts * div_multiplier, 1)

# %%
out = {}
for c, p in contracts.items():
    out[c] = number_of_contracts(p, target_vol=.4)
out
# Out:
# {'NQ': 15.8, 'ES': 5.8, 'GC': 6.0, 'YM': 5.7}
