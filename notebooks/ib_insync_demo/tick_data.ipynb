# %% [markdown]
# # Tick data
#
# For optimum results this notebook should be run during the Forex trading session.

# %%
from ib_insync import *
util.startLoop()

ib = IB()
ib.connect('127.0.0.1', 4002, clientId=15)
# Out:
# <IB connected to 127.0.0.1:4002 clientId=15>

# %% [markdown]
# ### Streaming tick data
#
# Create some Forex contracts:

# %%
contracts = [Forex(pair) for pair in ('EURUSD', 'USDJPY', 'GBPUSD', 'USDCHF', 'USDCAD', 'AUDUSD')]
ib.qualifyContracts(*contracts)

eurusd = contracts[0]

# %% [markdown]
# Request streaming ticks for them:

# %%
for contract in contracts:
    ib.reqMktData(contract, '', False, False)

# %% [markdown]
# Wait a few seconds for the tickers to get filled.

# %%
ticker = ib.ticker(eurusd)
ib.sleep(2)

ticker
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), time=datetime.datetime(2019, 9, 23, 9, 52, 43, 601018, tzinfo=datetime.timezone.utc), bid=1.09815, bidSize=5000000, ask=1.09816, askSize=2000000, prevBid=1.09814, prevBidSize=2000000, prevAsk=1.09815, prevAskSize=3000000, high=1.10255, low=1.0966, close=1.102, ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[])

# %% [markdown]
# The price of Forex ticks is always nan. To get a midpoint price use ``midpoint()`` or ``marketPrice()``.
#
# The tickers are kept live updated, try this a few times to see if the price changes:

# %%
ticker.marketPrice()
# Out:
# 1.098145

# %%
type(ticker)
# Out:
# ib_insync.ticker.Ticker

# %% [markdown]
# The following cell will start a 30 second loop that prints a live updated ticker table.
# It is updated on every ticker change.

# %%
from IPython.display import display, clear_output
import pandas as pd

df = pd.DataFrame(
    index=[c.pair() for c in contracts],
    columns=['bidSize', 'bid', 'ask', 'askSize', 'high', 'low', 'close'])

def onPendingTickers(tickers):
    for t in tickers:
        df.loc[t.contract.pair()] = (
            t.bidSize, t.bid, t.ask, t.askSize, t.high, t.low, t.close)
        clear_output(wait=True)
    display(df)        

ib.pendingTickersEvent += onPendingTickers
ib.sleep(30)
ib.pendingTickersEvent -= onPendingTickers
# Out:
#         bidSize      bid      ask  askSize     high      low   close
# EURUSD  5000000  1.09818  1.09819  2000000  1.10255   1.0966   1.102
# USDJPY  1000000  107.499    107.5  2000000   107.77   107.31  107.56
# GBPUSD  1000000  1.24451  1.24455  2000000   1.2491   1.2423  1.2474
# USDCHF  1000000  0.99101  0.99104  2000000  0.99225   0.9893  0.9909
# USDCAD  1000000  1.32996     1.33  2000000  1.33055  1.32635  1.3263
# AUDUSD  2000000  0.67711  0.67714  6500000  0.67815   0.6765  0.6766

# %% [markdown]
# New tick data is available in the 'ticks' attribute of the pending tickers.
# The tick data will be cleared before the next update.

# %% [markdown]
# To stop the live tick subscriptions:

# %%
for contract in contracts:
    ib.cancelMktData(contract)

# %% [markdown]
# ### Tick by Tick data ###
#
# The ticks in the previous section are time-sampled by IB in order to cut on bandwidth. So with ``reqMktdData`` not every tick from the exchanges is sent. The promise of ``reqTickByTickData`` is to send every tick, just how it appears in the TWS Time & Sales window. This functionality is severly nerfed by a total of just three simultaneous subscriptions, where bid-ask ticks and sale ticks also use up a subscription each.
#
# The tick-by-tick updates are available from ``ticker.tickByTicks`` and are signalled by ``ib.pendingTickersEvent`` or ``ticker.updateEvent``.

# %%
ticker = ib.reqTickByTickData(eurusd, 'BidAsk')
ib.sleep(2)
print(ticker)

ib.cancelTickByTickData(ticker.contract, 'BidAsk')
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), time=datetime.datetime(2019, 7, 11, 17, 33, 53, 662953, tzinfo=datetime.timezone.utc), bid=1.12479, bidSize=4000000, ask=1.12481, askSize=4000000, prevBid=1.12476, prevBidSize=2000000, prevAsk=1.12479, prevAskSize=12000000, high=1.12855, low=1.1245, close=1.1251, ticks=[], tickByTicks=[TickByTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 33, 53, 662953, tzinfo=datetime.timezone.utc), bidPrice=1.12479, askPrice=1.12481, bidSize=4000000, askSize=4000000, tickAttribBidAsk=TickAttribBidAsk())], domBids=[], domAsks=[], domTicks=[])

# %% [markdown]
# ### Historical tick data
#
# Historical tick data can be fetched with a maximum of 1000 ticks at a time. Either the start time or the end time must be given, and one of them must remain empty:

# %%
import datetime

start = ''
end = datetime.datetime.now()
ticks = ib.reqHistoricalTicks(eurusd, start, end, 1000, 'BID_ASK', useRth=False)

ticks[-1]
# Out:
# HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=1000000)

# %%
ticks
# Out:
# [HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 27, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=5500000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12482, sizeBid=5500000, sizeAsk=7000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12482, sizeBid=5500000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12482, sizeBid=5500000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=5500000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=3500000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 28, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 29, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 29, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=5000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 29, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=4000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 29, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=2000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=4000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.1248, sizeBid=4000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.1248, sizeBid=4000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=4000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=4000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 31, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.
000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12476, sizeBid=3000000, sizeAsk=8000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=2000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12474, priceAsk=1.12475, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12473, priceAsk=1.12474, sizeBid=4000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12473, priceAsk=1.12474, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12473, priceAsk=1.12474, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12473, priceAsk=1.12474, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 32, 52, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12473, priceAsk=1.12474, sizeBid=1000000, sizeAsk=3000000),
# ...
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 11, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 11, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 11, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 11, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 12, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 12, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 12, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=2500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=5500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=6500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=5500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=4500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=3500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=2000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=4500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 13, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 14, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=3000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 14, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 14, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 14, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 15, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 15, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=3000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 15, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 15, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 15, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=6500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=6000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 16, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12478, priceAsk=1.12479, sizeBid=2000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=2000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=3000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=3000000, sizeAsk=1000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.12481, sizeBid=3000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=1000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=2000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 17, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=7000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=9000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.12479, priceAsk=1.1248, sizeBid=1000000, sizeAsk=3500000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=3000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=4000000),
#  HistoricalTickBidAsk(time=datetime.datetime(2019, 7, 11, 17, 34, 18, tzinfo=datetime.timezone.utc), tickAttribBidAsk=TickAttribBidAsk(), priceBid=1.1248, priceAsk=1.12481, sizeBid=2000000, sizeAsk=5000000),
#  ...]

# %%
util.df(ticks)
# Out:
#                           time    tickAttribBidAsk  priceBid  priceAsk  \
# 0    2019-07-11 17:32:27+00:00  TickAttribBidAsk()   1.12479   1.12481
# 1    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12479   1.12481
# 2    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 3    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 4    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 5    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 6    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 7    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 8    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 9    2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 10   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 11   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12482
# 12   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12482
# 13   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12482
# 14   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 15   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 16   2019-07-11 17:32:28+00:00  TickAttribBidAsk()   1.12480   1.12481
# 17   2019-07-11 17:32:29+00:00  TickAttribBidAsk()   1.12480   1.12481
# 18   2019-07-11 17:32:29+00:00  TickAttribBidAsk()   1.12479   1.12481
# 19   2019-07-11 17:32:29+00:00  TickAttribBidAsk()   1.12479   1.12481
# 20   2019-07-11 17:32:29+00:00  TickAttribBidAsk()   1.12479   1.12481
# 21   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 22   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 23   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 24   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 25   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 26   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12479   1.12480
# 27   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12478   1.12479
# 28   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12478   1.12480
# 29   2019-07-11 17:32:31+00:00  TickAttribBidAsk()   1.12478   1.12480
# ...                        ...                 ...       ...       ...
# 974  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 975  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 976  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 977  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 978  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 979  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12481
# 980  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12480
# 981  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12479   1.12481
# 982  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12480   1.12481
# 983  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12480   1.12481
# 984  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12480   1.12481
# 985  2019-07-11 17:34:17+00:00  TickAttribBidAsk()   1.12480   1.12481
# 986  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 987  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 988  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 989  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 990  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 991  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 992  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 993  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12479   1.12480
# 994  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 995  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 996  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 997  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 998  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 999  2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 1000 2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 1001 2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 1002 2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
# 1003 2019-07-11 17:34:18+00:00  TickAttribBidAsk()   1.12480   1.12481
#
#       sizeBid  sizeAsk
# 0     2000000  5000000
# 1     2000000  4000000
# 2     2000000  4000000
# 3     2000000  5000000
# 4     2000000  6000000
# 5     2000000  5000000
# 6     2000000  4000000
# 7     3000000  3000000
# 8     3000000  2000000
# 9     3000000  1000000
# 10    5500000  1000000
# 11    5500000  7000000
# 12    5500000  6000000
# 13    5500000  5000000
# 14    5500000  1000000
# 15    3500000  1000000
# 16    1000000  1000000
# 17    1000000  2000000
# 18    5000000  3000000
# 19    4000000  3000000
# 20    3000000  3000000
# 21    3000000  1000000
# 22    2000000  1000000
# 23    1000000  1000000
# 24    1000000  2000000
# 25    1000000  1000000
# 26    1000000  2000000
# 27    4000000  3000000
# 28    4000000  4000000
# 29    4000000  5000000
# ...       ...      ...
# 974   1000000  4000000
# 975   1000000  3000000
# 976   2000000  2000000
# 977   3000000  2000000
# 978   3000000  1000000
# 979   3000000  3000000
# 980   3000000  1000000
# 981   3000000  2000000
# 982   1000000  2000000
# 983   2000000  2000000
# 984   2000000  3000000
# 985   2000000  4000000
# 986   2000000  7000000
# 987   2000000  4000000
# 988   2000000  5000000
# 989   2000000  4000000
# 990   2000000  5000000
# 991   2000000  4000000
# 992   2000000  9000000
# 993   1000000  3500000
# 994   2000000  4000000
# 995   2000000  3000000
# 996   2000000  4000000
# 997   2000000  3000000
# 998   2000000  4000000
# 999   2000000  5000000
# 1000  2000000  4000000
# 1001  2000000  3000000
# 1002  2000000  2000000
# 1003  2000000  1000000
#
# [1004 rows x 6 columns]

# %%
ib.disconnect()
