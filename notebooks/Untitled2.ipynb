# %%
from rx import Observable, Observer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d21ce50f9a50> in <module>
# ----> 1 from rx import Observable, Observer
#
# ImportError: cannot import name 'Observer' from 'rx' (/home/tomek/.virtualenvs/ib/lib/python3.7/site-packages/rx/__init__.py)
