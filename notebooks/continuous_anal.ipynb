# %%
import pandas as pd
# %matplotlib inline

# %%
cont = pd.read_pickle('minute_NQ_cont_non_active_included.pickle')
cont.head()
# Out:
#                        open    high     low   close  volume  average  barCount
# date
# 2016-12-01 07:26:00  4818.0  4818.0  4818.0  4818.0       5   4818.0         4
# 2016-12-01 07:27:00  4818.0  4818.0  4818.0  4818.0       0   4818.0         0
# 2016-12-01 07:28:00  4818.0  4818.0  4818.0  4818.0       0   4818.0         0
# 2016-12-01 07:29:00  4818.0  4818.0  4818.0  4818.0       0   4818.0         0
# 2016-12-01 07:30:00  4818.0  4818.0  4818.0  4818.0       0   4818.0         0

# %%
cont.close.plot(figsize=(20,10), grid=True);

# %%
cont.loc['20190621 22:50':'20190622 2:00'].head(30)
# Out:
#                         open     high      low    close  volume   average  \
# date
# 2019-06-21 22:50:00  7753.50  7753.75  7752.50  7753.25     139  7753.125
# 2019-06-21 22:51:00  7753.25  7753.25  7751.25  7751.25      63  7752.450
# 2019-06-21 22:52:00  7751.50  7751.75  7750.75  7750.75      61  7751.225
# 2019-06-21 22:53:00  7751.00  7752.00  7750.75  7751.00      35  7751.175
# 2019-06-21 22:54:00  7751.00  7751.50  7750.50  7751.00      39  7750.975
# 2019-06-21 22:55:00  7751.00  7751.50  7749.75  7750.00      66  7750.400
# 2019-06-21 22:56:00  7750.00  7750.00  7749.50  7749.75      20  7749.775
# 2019-06-21 22:57:00  7749.75  7749.75  7748.00  7748.00      68  7748.700
# 2019-06-21 22:58:00  7748.00  7748.50  7748.00  7748.00      74  7748.125
# 2019-06-21 22:59:00  7748.25  7749.25  7746.00  7746.75     164  7747.375
#
#                      barCount
# date
# 2019-06-21 22:50:00        69
# 2019-06-21 22:51:00        41
# 2019-06-21 22:52:00        43
# 2019-06-21 22:53:00        25
# 2019-06-21 22:54:00        20
# 2019-06-21 22:55:00        26
# 2019-06-21 22:56:00         9
# 2019-06-21 22:57:00        27
# 2019-06-21 22:58:00        38
# 2019-06-21 22:59:00        81

# %%
cont.loc['20190611 22:45':'20190613 2:00'].close.plot(figsize=(20,10), grid=True);

# %%
    def third_friday(symbol):
        """
        Return third Friday of the expiration month for the passed symbol.
        Used as a fallback if real expiration date cannot be found.
        """
        year = int(symbol[-4:])
        month = int(CME_CODE_TO_MONTH[symbol[-5]])
        c = cal.Calendar(firstweekday=cal.SATURDAY)
        day = c.monthdatescalendar(year, month)[2][-1]
        return pd.to_datetime(day)
